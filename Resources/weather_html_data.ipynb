# %%
# Dependencies
import os
import pandas as pd

# %%
file_path = os.path.join('../Resources/cities.csv')
cities = pd.read_csv(file_path)

# %%
cities_df = pd.DataFrame(cities)

# %%
cities_df
# Out:
#      City_ID                City  Cloudiness Country        Date  Humidity  \
# 0          0        jacareacanga           0      BR  1528902000        62
# 1          1          kaitangata         100      NZ  1528905304        94
# 2          2            goulburn          20      AU  1528905078        91
# 3          3                lata          76      IN  1528905305        89
# 4          4          chokurdakh           0      RU  1528905306        88
# 5          5            martyush          92      RU  1528905306        94
# 6          6              hobart          20      AU  1528902000        87
# 7          7         broken hill           0      AU  1528905311        88
# 8          8           harnosand           0      SE  1528903200        44
# 9          9           tuatapere           0      NZ  1528905312       100
# 10        10        puerto ayora          90      EC  1528902000        69
# ...

# %%
cities = cities_df.reset_index(drop=True)
cities.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
cities_data = cities.rename(columns = {"City_ID":"City ID",
                                      "City":"City Name",
                                      "Cloudiness":"Cloudiness",
                                      "County":"County",
                                      "Date":"Date",
                                      "Humidity":"Humidity %",
                                      "Lat":"Latitude",
                                      "Lng":"Longitude",
                                      "Max Temp":"Max Temperature(F)",
                                      "Wind Speed":"Wind Speed(MPH)"})
cities_data
# Out:
#      City ID           City Name  Cloudiness Country        Date  Humidity %  \
# 0          0        jacareacanga           0      BR  1528902000          62
# 1          1          kaitangata         100      NZ  1528905304          94
# 2          2            goulburn          20      AU  1528905078          91
# 3          3                lata          76      IN  1528905305          89
# 4          4          chokurdakh           0      RU  1528905306          88
# 5          5            martyush          92      RU  1528905306          94
# 6          6              hobart          20      AU  1528902000          87
# 7          7         broken hill           0      AU  1528905311          88
# 8          8           harnosand           0      SE  1528903200          44
# 9          9           tuatapere           0      NZ  1528905312         100
# 10        10        puerto ayora          90      EC  1528902000          69
# ...

# %%
cities_data["Date"] = pd.to_datetime(cities_data['Date'])
cities_data
# Out:
#      City ID           City Name  Cloudiness Country  \
# 0          0        jacareacanga           0      BR
# 1          1          kaitangata         100      NZ
# 2          2            goulburn          20      AU
# 3          3                lata          76      IN
# 4          4          chokurdakh           0      RU
# 5          5            martyush          92      RU
# 6          6              hobart          20      AU
# 7          7         broken hill           0      AU
# 8          8           harnosand           0      SE
# 9          9           tuatapere           0      NZ
# 10        10        puerto ayora          90      EC
# 11        11  havre-saint-pierre          75      CA
# 12        12        punta arenas           0      CL
# 13        13            tasiilaq          75      GL
# 14        14             chapais          40      CA
# 15        15              avarua          40      CK
# 16        16                hofn          75      IS
# ...

# %%
cities_data.to_html('../Resources/data.html')
